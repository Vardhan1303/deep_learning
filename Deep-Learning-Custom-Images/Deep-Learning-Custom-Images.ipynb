# %% [markdown]
# # Working with Custom Images
#
# ## The Data
#
# ----------
# --------
#
# ORIGINAL DATA SOURCE:
#
# https://www.microsoft.com/en-us/download/confirmation.aspx?id=54765
#
# -----------
#
# The Kaggle Competition: [Cats and Dogs](https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition) includes 25,000 images of cats and dogs. We will be building a classifier that works with these images and attempt to detect dogs versus cats!
#
# The pictures are numbered 0-12499 for both cats and dogs, thus we have 12,500 images of Dogs and 12,500 images of Cats. This is a huge dataset!!
#
# --------
# ----------
# ------------
#
#
# **Note: We will be dealing with real image files, NOT numpy arrays. Which means a large part of this process will be learning how to work with and deal with large groups of image files. This is too much data to fit in memory as a numpy array, so we'll need to feed it into our model in batches. **
#
# ### Visualizing the Data
#
#
# -------
# Let's take a closer look at the data.

# %%
import matplotlib.pyplot as plt
import cv2
# Technically not necessary in newest versions of jupyter
# %matplotlib inline

# %%
cat4 = cv2.imread('./DATA/CATS_DOGS/train/CAT/4.jpg')
cat4 = cv2.cvtColor(cat4, cv2.COLOR_BGR2RGB)

# %%
type(cat4)
# Out:
# numpy.ndarray

# %%
cat4.shape
# Out:
# (375, 500, 3)

# %%
plt.imshow(cat4)

# %%
dog2 = cv2.imread('./DATA/CATS_DOGS/train/Dog/2.jpg')
dog2 = cv2.cvtColor(dog2,cv2.COLOR_BGR2RGB)

# %%
dog2.shape
# Out:
# (199, 188, 3)

# %%
plt.imshow(dog2)

# %% [markdown]
# ## Preparing the Data for the model
#
# There is too much data for us to read all at once in memory. We can use some built in functions in Keras to automatically process the data, generate a flow of batches from a directory, and also manipulate the images.
#
# ### Image Manipulation
#
# Its usually a good idea to manipulate the images with rotation, resizing, and scaling so the model becomes more robust to different images that our data set doesn't have. We can use the **ImageDataGenerator** to do this automatically for us. Check out the documentation for a full list of all the parameters you can use here!

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=30, # rotate the image 30 degrees
                               width_shift_range=0.1, # Shift the pic width by a max of 10%
                               height_shift_range=0.1, # Shift the pic height by a max of 10%
                               rescale=1/255, # Rescale the image by normalzing it.
                               shear_range=0.2, # Shear means cutting away part of the image (max 20%)
                               zoom_range=0.2, # Zoom in by 20% max
                               horizontal_flip=True, # Allo horizontal flipping
                               fill_mode='nearest' # Fill in missing pixels with the nearest filled value
                              )

# %%
plt.imshow(image_gen.random_transform(dog2))

# %%
plt.imshow(image_gen.random_transform(dog2))

# %%
plt.imshow(image_gen.random_transform(dog2))

# %% [markdown]
# ### Generating many manipulated images from a directory
#
#
# In order to use .flow_from_directory, you must organize the images in sub-directories. This is an absolute requirement, otherwise the method won't work. The directories should only contain images of one class, so one folder per class of images.
#
# Structure Needed:
#
# * Image Data Folder
#     * Class 1
#         * 0.jpg
#         * 1.jpg
#         * ...
#     * Class 2
#         * 0.jpg
#         * 1.jpg
#         * ...
#     * ...
#     * Class n

# %%
image_gen.flow_from_directory('./DATA/CATS_DOGS/train')
# Out:
# Found 18743 images belonging to 2 classes.

# %%
image_gen.flow_from_directory('./DATA/CATS_DOGS/test')
# Out:
# Found 6251 images belonging to 2 classes.

# %% [markdown]
# ### Resizing Images
#
# Let's have Keras resize all the images to 150 pixels by 150 pixels once they've been manipulated.

# %%
# width,height,channels
image_shape = (150,150,3)

# %% [markdown]
# # Creating the Model

# %%
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3,3),input_shape=(150,150,3), activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=(150,150,3), activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=(150,150,3), activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())


model.add(Dense(128))
model.add(Activation('relu'))

# Dropouts help reduce overfitting by randomly turning neurons off during training.
# Here we say randomly turn off 50% of neurons.
model.add(Dropout(0.5))

# Last layer, remember its binary, 0=cat , 1=dog
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 34, 34, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 17, 17, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 18496)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     2,367,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,424,065 (9.25 MB)
#  Trainable params: 2,424,065 (9.25 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training the Model

# %%
batch_size = 16

train_image_gen = image_gen.flow_from_directory('./DATA/CATS_DOGS/train',
                                               target_size=image_shape[:2],
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 18743 images belonging to 2 classes.

# %%
test_image_gen = image_gen.flow_from_directory('./DATA/CATS_DOGS/test',
                                               target_size=image_shape[:2],
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 6251 images belonging to 2 classes.

# %%
train_image_gen.class_indices
# Out:
# {'CAT': 0, 'DOG': 1}

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow

# %%
print(tensorflow.__version__)
# Out:
# 2.18.0

# %%
results = model.fit(train_image_gen,epochs=100,
                              steps_per_epoch=150,
                              validation_data=test_image_gen,
                             validation_steps=12)
# Out:
# Epoch 1/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - accuracy: 0.5194 - loss: 0.7282 - val_accuracy: 0.4531 - val_loss: 0.6898
# Epoch 2/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 87ms/step - accuracy: 0.5575 - loss: 0.6878 - val_accuracy: 0.4792 - val_loss: 0.7418
# Epoch 3/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.5671 - loss: 0.6882 - val_accuracy: 0.5469 - val_loss: 0.6816
# Epoch 4/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.5652 - loss: 0.6854 - val_accuracy: 0.5677 - val_loss: 0.6818
# Epoch 5/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.5566 - loss: 0.6856 - val_accuracy: 0.5417 - val_loss: 0.6863
# Epoch 6/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 78ms/step - accuracy: 0.5708 - loss: 0.6769 - val_accuracy: 0.5677 - val_loss: 0.6853
# Epoch 7/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.5468 - loss: 0.6830 - val_accuracy: 0.6198 - val_loss: 0.6548
# Epoch 8/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.6220 - loss: 0.6623 - val_accuracy: 0.6615 - val_loss: 0.6276
# Epoch 9/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.6114 - loss: 0.6668 - val_accuracy: 0.6615 - val_loss: 0.6210
# Epoch 10/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.6317 - loss: 0.6467 - val_accuracy: 0.6562 - val_loss: 0.6172
# Epoch 11/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.6568 - loss: 0.6278 - val_accuracy: 0.5990 - val_loss: 0.6513
# Epoch 12/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.6715 - loss: 0.6215 - val_accuracy: 0.7292 - val_loss: 0.5884
# Epoch 13/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 88ms/step - accuracy: 0.6776 - loss: 0.6192 - val_accuracy: 0.7188 - val_loss: 0.5582
# Epoch 14/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 77ms/step - accuracy: 0.6873 - loss: 0.6038 - val_accuracy: 0.6667 - val_loss: 0.6322
# Epoch 15/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.6757 - loss: 0.6156 - val_accuracy: 0.6719 - val_loss: 0.6036
# Epoch 16/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.6885 - loss: 0.5962 - val_accuracy: 0.7344 - val_loss: 0.5424
# Epoch 17/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.6924 - loss: 0.6067 - val_accuracy: 0.7240 - val_loss: 0.5595
# Epoch 18/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.6957 - loss: 0.5933 - val_accuracy: 0.7448 - val_loss: 0.5211
# Epoch 19/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 80ms/step - accuracy: 0.7149 - loss: 0.5721 - val_accuracy: 0.7552 - val_loss: 0.5033
# Epoch 20/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.6963 - loss: 0.5740 - val_accuracy: 0.7708 - val_loss: 0.5007
# Epoch 21/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - accuracy: 0.7217 - loss: 0.5492 - val_accuracy: 0.7188 - val_loss: 0.5190
# Epoch 22/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7011 - loss: 0.5689 - val_accuracy: 0.6875 - val_loss: 0.5763
# Epoch 23/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7174 - loss: 0.5481 - val_accuracy: 0.7500 - val_loss: 0.5061
# Epoch 24/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.7145 - loss: 0.5567 - val_accuracy: 0.7604 - val_loss: 0.5445
# Epoch 25/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7246 - loss: 0.5507 - val_accuracy: 0.8021 - val_loss: 0.4763
# Epoch 26/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.7351 - loss: 0.5271 - val_accuracy: 0.7708 - val_loss: 0.4716
# Epoch 27/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - accuracy: 0.7315 - loss: 0.5399 - val_accuracy: 0.7917 - val_loss: 0.4702
# Epoch 28/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.7286 - loss: 0.5377 - val_accuracy: 0.7292 - val_loss: 0.5170
# Epoch 29/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 79ms/step - accuracy: 0.7696 - loss: 0.5003 - val_accuracy: 0.7760 - val_loss: 0.4272
# Epoch 30/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 79ms/step - accuracy: 0.7398 - loss: 0.5419 - val_accuracy: 0.7135 - val_loss: 0.5521
# Epoch 31/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 77ms/step - accuracy: 0.7467 - loss: 0.5233 - val_accuracy: 0.7604 - val_loss: 0.4788
# Epoch 32/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.7464 - loss: 0.5069 - val_accuracy: 0.7604 - val_loss: 0.4733
# Epoch 33/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.7430 - loss: 0.5209 - val_accuracy: 0.7448 - val_loss: 0.5250
# Epoch 34/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 79ms/step - accuracy: 0.7457 - loss: 0.5060 - val_accuracy: 0.7865 - val_loss: 0.4938
# Epoch 35/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.7643 - loss: 0.4920 - val_accuracy: 0.7917 - val_loss: 0.4721
# Epoch 36/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 78ms/step - accuracy: 0.7589 - loss: 0.5031 - val_accuracy: 0.7812 - val_loss: 0.4587
# Epoch 37/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 80ms/step - accuracy: 0.7696 - loss: 0.4936 - val_accuracy: 0.7448 - val_loss: 0.5163
# Epoch 38/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 78ms/step - accuracy: 0.7525 - loss: 0.5126 - val_accuracy: 0.7656 - val_loss: 0.4734
# Epoch 39/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.7459 - loss: 0.5183 - val_accuracy: 0.7500 - val_loss: 0.5184
# Epoch 40/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.7751 - loss: 0.4874 - val_accuracy: 0.7812 - val_loss: 0.4933
# Epoch 41/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 77ms/step - accuracy: 0.7490 - loss: 0.5016 - val_accuracy: 0.7760 - val_loss: 0.4287
# Epoch 42/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.7617 - loss: 0.5017 - val_accuracy: 0.8021 - val_loss: 0.4430
# Epoch 43/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 78ms/step - accuracy: 0.7673 - loss: 0.4774 - val_accuracy: 0.7917 - val_loss: 0.4617
# Epoch 44/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.7584 - loss: 0.5027 - val_accuracy: 0.8281 - val_loss: 0.4007
# Epoch 45/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.7760 - loss: 0.4746 - val_accuracy: 0.7344 - val_loss: 0.5200
# Epoch 46/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.7770 - loss: 0.4659 - val_accuracy: 0.7865 - val_loss: 0.4402
# Epoch 47/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.7750 - loss: 0.4747 - val_accuracy: 0.7760 - val_loss: 0.4867
# Epoch 48/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.7703 - loss: 0.4589 - val_accuracy: 0.8385 - val_loss: 0.3841
# Epoch 49/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.7857 - loss: 0.4658 - val_accuracy: 0.7812 - val_loss: 0.4331
# Epoch 50/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.7811 - loss: 0.4683 - val_accuracy: 0.7656 - val_loss: 0.4661
# Epoch 51/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.7984 - loss: 0.4446 - val_accuracy: 0.8125 - val_loss: 0.4442
# Epoch 52/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7838 - loss: 0.4530 - val_accuracy: 0.8333 - val_loss: 0.4811
# Epoch 53/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.7827 - loss: 0.4644 - val_accuracy: 0.7917 - val_loss: 0.4755
# Epoch 54/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - accuracy: 0.7895 - loss: 0.4606 - val_accuracy: 0.7865 - val_loss: 0.4429
# Epoch 55/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.7884 - loss: 0.4641 - val_accuracy: 0.8125 - val_loss: 0.4415
# Epoch 56/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.7895 - loss: 0.4451 - val_accuracy: 0.7917 - val_loss: 0.4473
# Epoch 57/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.7906 - loss: 0.4638 - val_accuracy: 0.8698 - val_loss: 0.3224
# Epoch 58/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7926 - loss: 0.4656 - val_accuracy: 0.8125 - val_loss: 0.3654
# Epoch 59/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7916 - loss: 0.4523 - val_accuracy: 0.8281 - val_loss: 0.4066
# Epoch 60/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7903 - loss: 0.4467 - val_accuracy: 0.7969 - val_loss: 0.4681
# Epoch 61/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - accuracy: 0.7858 - loss: 0.4413 - val_accuracy: 0.7812 - val_loss: 0.4638
# Epoch 62/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.8011 - loss: 0.4411 - val_accuracy: 0.8021 - val_loss: 0.4786
# Epoch 63/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.7942 - loss: 0.4495 - val_accuracy: 0.8125 - val_loss: 0.4003
# Epoch 64/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.7824 - loss: 0.4492 - val_accuracy: 0.7240 - val_loss: 0.5143
# Epoch 65/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 80ms/step - accuracy: 0.7876 - loss: 0.4475 - val_accuracy: 0.8073 - val_loss: 0.4139
# Epoch 66/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7925 - loss: 0.4355 - val_accuracy: 0.7812 - val_loss: 0.4686
# Epoch 67/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.7914 - loss: 0.4352 - val_accuracy: 0.7760 - val_loss: 0.4889
# Epoch 68/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.8040 - loss: 0.4263 - val_accuracy: 0.8229 - val_loss: 0.3929
# Epoch 69/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - accuracy: 0.8161 - loss: 0.4105 - val_accuracy: 0.7552 - val_loss: 0.4592
# Epoch 70/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.7983 - loss: 0.4337 - val_accuracy: 0.8333 - val_loss: 0.4410
# Epoch 71/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.7847 - loss: 0.4600 - val_accuracy: 0.7448 - val_loss: 0.4723
# Epoch 72/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.8126 - loss: 0.4205 - val_accuracy: 0.7917 - val_loss: 0.4066
# Epoch 73/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.8086 - loss: 0.4326 - val_accuracy: 0.8021 - val_loss: 0.4351
# Epoch 74/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.8175 - loss: 0.4334 - val_accuracy: 0.8646 - val_loss: 0.3425
# Epoch 75/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7956 - loss: 0.4386 - val_accuracy: 0.7812 - val_loss: 0.4594
# Epoch 76/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.7947 - loss: 0.4397 - val_accuracy: 0.8125 - val_loss: 0.4035
# Epoch 77/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.8163 - loss: 0.4192 - val_accuracy: 0.7812 - val_loss: 0.5574
# Epoch 78/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.8148 - loss: 0.4344 - val_accuracy: 0.7917 - val_loss: 0.4249
# Epoch 79/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.8024 - loss: 0.4493 - val_accuracy: 0.8073 - val_loss: 0.4195
# Epoch 80/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.8174 - loss: 0.4014 - val_accuracy: 0.7760 - val_loss: 0.5506
# Epoch 81/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.8014 - loss: 0.4327 - val_accuracy: 0.8594 - val_loss: 0.3516
# Epoch 82/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.7949 - loss: 0.4387 - val_accuracy: 0.8177 - val_loss: 0.3980
# Epoch 83/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.8011 - loss: 0.4362 - val_accuracy: 0.8438 - val_loss: 0.3919
# Epoch 84/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.8092 - loss: 0.4343 - val_accuracy: 0.8021 - val_loss: 0.4145
# Epoch 85/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.8185 - loss: 0.3955 - val_accuracy: 0.8073 - val_loss: 0.4194
# Epoch 86/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.8247 - loss: 0.4261 - val_accuracy: 0.8177 - val_loss: 0.3899
# Epoch 87/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.8080 - loss: 0.4164 - val_accuracy: 0.8125 - val_loss: 0.3943
# Epoch 88/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.8251 - loss: 0.3922 - val_accuracy: 0.8333 - val_loss: 0.3396
# Epoch 89/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.8324 - loss: 0.3885 - val_accuracy: 0.8438 - val_loss: 0.3751
# Epoch 90/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.8028 - loss: 0.4085 - val_accuracy: 0.8125 - val_loss: 0.3980
# Epoch 91/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.8154 - loss: 0.4088 - val_accuracy: 0.8177 - val_loss: 0.3944
# Epoch 92/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - accuracy: 0.8026 - loss: 0.4355 - val_accuracy: 0.7865 - val_loss: 0.4609
# Epoch 93/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.8061 - loss: 0.4217 - val_accuracy: 0.8438 - val_loss: 0.3940
# Epoch 94/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.8304 - loss: 0.3874 - val_accuracy: 0.8021 - val_loss: 0.4056
# Epoch 95/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.8249 - loss: 0.3868 - val_accuracy: 0.8177 - val_loss: 0.4142
# Epoch 96/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.8367 - loss: 0.4067 - val_accuracy: 0.8594 - val_loss: 0.3814
# Epoch 97/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.8091 - loss: 0.4049 - val_accuracy: 0.8333 - val_loss: 0.4471
# Epoch 98/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.8189 - loss: 0.4181 - val_accuracy: 0.8177 - val_loss: 0.4373
# Epoch 99/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.8282 - loss: 0.4053 - val_accuracy: 0.8229 - val_loss: 0.4474
# Epoch 100/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.8216 - loss: 0.3804 - val_accuracy: 0.8490 - val_loss: 0.3925

# %%
model.save('cat_dog2.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Evaluating the Model

# %%
results.history['accuracy']
# Out:
# [0.5165202617645264,
#  0.5620833039283752,
#  0.5645833611488342,
#  0.5420833230018616,
#  0.5733333230018616,
#  0.5795833468437195,
#  0.5745833516120911,
#  0.6152663826942444,
#  0.6233333349227905,
#  0.6258333325386047,
#  0.6474999785423279,
#  0.6595566868782043,
#  0.6679166555404663,
#  0.6899999976158142,
#  0.67208331823349,
#  0.6962090134620667,
#  0.6937500238418579,
#  0.6800000071525574,
#  0.7135089635848999,
#  0.7079166769981384,
#  0.7283333539962769,
#  0.7074999809265137,
#  0.7120833396911621,
#  0.7264344096183777,
#  0.7195833325386047,
#  0.7425000071525574,
#  0.7352572083473206,
#  0.7320833206176758,
#  0.7545833587646484,
#  0.7524999976158142,
#  0.7445833086967468,
#  0.7515369057655334,
#  0.7441666722297668,
#  0.7491666674613953,
#  0.759096622467041,
#  0.7629166841506958,
#  0.76541668176651,
#  0.7516666650772095,
#  0.7558333277702332,
#  0.780225396156311,
#  0.7670833468437195,
#  0.7608333230018616,
#  0.7645833492279053,
#  0.7716666460037231,
#  0.7766666412353516,
#  0.768750011920929,
#  0.777917206287384,
#  0.775102436542511,
#  0.7754166722297668,
#  0.777916669845581,
#  0.7887499928474426,
#  0.7770833373069763,
#  0.7799999713897705,
#  0.7820995450019836,
#  0.7862499952316284,
#  0.7971311211585999,
#  0.7900000214576721,
#  0.7925000190734863,
#  0.7912499904632568,
#  0.7979166507720947,
#  0.7812630534172058,
#  0.7979166507720947,
#  0.7854166626930237,
#  0.7909836173057556,
#  0.7887499928474426,
#  0.7958333492279053,
#  0.7933333516120911,
#  0.8012499809265137,
#  0.8071936368942261,
#  0.8004166483879089,
#  0.7904166579246521,
#  0.8053278923034668,
#  0.8020833134651184,
#  0.8183333277702332,
#  0.7995833158493042,
#  0.7995833158493042,
#  0.8197407126426697,
#  0.8195833563804626,
#  0.8020833134651184,
#  0.8176229596138,
#  0.8187500238418579,
#  0.8020833134651184,
#  0.8133333325386047,
#  0.8105395436286926,
#  0.8100000023841858,
#  0.8208333253860474,
#  0.8020833134651184,
#  0.8217213153839111,
#  0.8166666626930237,
#  0.8149999976158142,
#  0.8212500214576721,
#  0.8183333277702332,
#  0.8079166412353516,
#  0.8218318819999695,
#  0.8199999928474426,
#  0.8237704634666443,
#  0.8205771446228027,
#  0.8229166865348816,
#  0.8208333253860474,
#  0.8387500047683716]

# %%
plt.plot(results.history['accuracy'])

# %%
model.save('cat_dog_100epochs.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Predicting on new images

# %%
train_image_gen.class_indices
# Out:
# {'CAT': 0, 'DOG': 1}

# %%
import numpy as np
from keras.preprocessing import image

dog_file = './DATA/CATS_DOGS/train/Dog/2.jpg'

dog_img = image.load_img(dog_file, target_size=(150, 150))

dog_img = image.img_to_array(dog_img)

dog_img = np.expand_dims(dog_img, axis=0)
dog_img = dog_img/255

# %%
prediction_prob = model.predict(dog_img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step

# %%
# Output prediction
print(f'Probability that image is a dog is: {prediction_prob} ')
# Out:
# Probability that image is a dog is: [[0.97748446]]

# %% [markdown]
# # Great Job!
